# %%
import pandas as pd

# %%
scores = {'Zone': ['North', 'North', 'South', 'South','East', 'East', 'West', 'West'],            
          'School': ['Rushmore', 'Rushmore','Bayside','Rydell','Shermer','Shermer','Ridgemont','Hogwarts'],                        
          'Name': ['Jonny', 'Mary', 'Joe', 'Jakob', 'Jimmy', 'Erik', 'Lam', 'Yip'],            
          'Math': [78, 39, 76, 56, 67, 89, 100, 55], 
          'Science': [70, 45, 68, 90, 45, 66, 89, 32]}
scores
# Out:
# {'Zone': ['North', 'North', 'South', 'South', 'East', 'East', 'West', 'West'],
#  'School': ['Rushmore',
#   'Rushmore',
#   'Bayside',
#   'Rydell',
#   'Shermer',
#   'Shermer',
#   'Ridgemont',
#   'Hogwarts'],
#  'Name': ['Jonny', 'Mary', 'Joe', 'Jakob', 'Jimmy', 'Erik', 'Lam', 'Yip'],
#  'Math': [78, 39, 76, 56, 67, 89, 100, 55],
#  'Science': [70, 45, 68, 90, 45, 66, 89, 32]}

# %%
df = pd.DataFrame(scores)
df
# Out:
#     Zone     School   Name  Math  Science
# 0  North   Rushmore  Jonny    78       70
# 1  North   Rushmore   Mary    39       45
# 2  South    Bayside    Joe    76       68
# 3  South     Rydell  Jakob    56       90
# 4   East    Shermer  Jimmy    67       45
# 5   East    Shermer   Erik    89       66
# 6   West  Ridgemont    Lam   100       89
# 7   West   Hogwarts    Yip    55       32

# %%
group_science_by_school = df['Science'].groupby(df['School'])
pd.DataFrame(group_science_by_school)
# Out:
#            0                                            1
# 0    Bayside          2    68
# Name: Science, dtype: int64
# 1   Hogwarts          7    32
# Name: Science, dtype: int64
# 2  Ridgemont          6    89
# Name: Science, dtype: int64
# 3   Rushmore  0    70
# 1    45
# Name: Science, dtype: int64
# 4     Rydell          3    90
# Name: Science, dtype: int64
# 5    Shermer  4    45
# 5    66
# Name: Science, dtype: int64

# %%
for school,group in group_science_by_school:
    print(school)
    for i in group: #group is a Series, we loop through the series
        print (i)   #print values in the Series
    
    print(' ')
# Out:
# Bayside
# 68
#
# Hogwarts
# 32
#
# Ridgemont
# 89
#
# Rushmore
# 70
# 45
#
# Rydell
# 90
#
# Shermer
# 45
# 66

# %%
for school,group in group_science_by_school:
    print(school)
    for i in group.index: #group is a Series, we loop through the series
        print (df.loc[i,'Name'])   #print values in the Series
        print ('got ' + str(df.iloc[i]['Math']) + ' for Math')
    print(' ')
# Out:
# Bayside
# Joe
# got 76 for Math
#
# Hogwarts
# Yip
# got 55 for Math
#
# Ridgemont
# Lam
# got 100 for Math
#
# Rushmore
# Jonny
# got 78 for Math
# Mary
# got 39 for Math
#
# Rydell
# Jakob
# got 56 for Math
#
# Shermer
# Jimmy
# got 67 for Math
# Erik
# got 89 for Math

# %%
#descriptive statistics
group_science_by_school.describe()
# Out:
#            count  mean        std   min    25%   50%    75%   max
# School
# Bayside      1.0  68.0        NaN  68.0  68.00  68.0  68.00  68.0
# Hogwarts     1.0  32.0        NaN  32.0  32.00  32.0  32.00  32.0
# Ridgemont    1.0  89.0        NaN  89.0  89.00  89.0  89.00  89.0
# Rushmore     2.0  57.5  17.677670  45.0  51.25  57.5  63.75  70.0
# Rydell       1.0  90.0        NaN  90.0  90.00  90.0  90.00  90.0
# Shermer      2.0  55.5  14.849242  45.0  50.25  55.5  60.75  66.0

# %%
#we can get the mean directly
group_science_by_school.mean()
# Out:
# School
# Bayside      68.0
# Hogwarts     32.0
# Ridgemont    89.0
# Rushmore     57.5
# Rydell       90.0
# Shermer      55.5
# Name: Science, dtype: float64

# %%
group_science_by_school.std()
# Out:
# School
# Bayside            NaN
# Hogwarts           NaN
# Ridgemont          NaN
# Rushmore     17.677670
# Rydell             NaN
# Shermer      14.849242
# Name: Science, dtype: float64

# %%
df = pd.read_csv('csv_data.csv')

# %%
df
# Out:
#        year    make    model
# 0      2001   ACURA       CL
# 1      2001   ACURA       EL
# 2      2001   ACURA  INTEGRA
# 3      2001   ACURA      MDX
# 4      2001   ACURA      NSX
# ...     ...     ...      ...
# 19767  2015  YAMAHA    SR400
# 19768  2016     KIA  SORENTO
# 19769  2016   MAZDA        6
# 19770  2016   MAZDA     CX-5
# 19771  2016   VOLVO     XC90
#
# [19772 rows x 3 columns]

# %%
# Let's groupby our cars by year
cars_grouped_year = df.groupby(df['year'])
cars_grouped_year

# %%
df['year'].unique()
# Out:
# array([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016])

# %%
df['year'].value_counts().sort_index()
# Out:
# 2001    1215
# 2002    1291
# 2003    1310
# 2004    1379
# 2005    1385
# 2006    1412
# 2007    1461
# 2008    1476
# 2009    1439
# 2010    1316
# 2011    1322
# 2012    1318
# 2013    1388
# 2014    1361
# 2015     695
# 2016       4
# Name: year, dtype: int64

# %%
#getting first item in the list
list(cars_grouped_year)[0][1]
# Out:
#       year    make    model
# 0     2001   ACURA       CL
# 1     2001   ACURA       EL
# 2     2001   ACURA  INTEGRA
# 3     2001   ACURA      MDX
# 4     2001   ACURA      NSX
# ...    ...     ...      ...
# 1210  2001  YAMAHA   YZ426F
# 1211  2001  YAMAHA     YZ80
# 1212  2001  YAMAHA   YZF-R1
# 1213  2001  YAMAHA   YZF-R6
# 1214  2001  YAMAHA  YZF600R
#
# [1215 rows x 3 columns]

# %%
for year, group in car

# %%
cars_grouped_year = df[['make','model']].groupby(df['year'])

for year,group in cars_grouped_year:
    print(year)
    print(group)
# Out:
# 2001
#         make    model
# 0      ACURA       CL
# 1      ACURA       EL
# 2      ACURA  INTEGRA
# 3      ACURA      MDX
# 4      ACURA      NSX
# ...      ...      ...
# 1210  YAMAHA   YZ426F
# 1211  YAMAHA     YZ80
# 1212  YAMAHA   YZF-R1
# 1213  YAMAHA   YZF-R6
# 1214  YAMAHA  YZF600R
#
# [1215 rows x 2 columns]
# 2002
#         make    model
# 1215   ACURA       CL
# 1216   ACURA       EL
# 1217   ACURA      MDX
# 1218   ACURA      NSX
# 1219   ACURA       RL
# ...      ...      ...
# 2501  YAMAHA   YZ426F
# 2502  YAMAHA     YZ85
# 2503  YAMAHA   YZF-R1
# 2504  YAMAHA   YZF-R6
# 2505  YAMAHA  YZF600R
#
# [1291 rows x 2 columns]
# 2003
#         make    model
# 2506   ACURA       CL
# 2507   ACURA       EL
# 2508   ACURA      MDX
# 2509   ACURA      NSX
# 2510   ACURA       RL
# ...      ...      ...
# 3811  YAMAHA   YZ450F
# 3812  YAMAHA     YZ85
# 3813  YAMAHA   YZF-R1
# 3814  YAMAHA   YZF-R6
# 3815  YAMAHA  YZF600R
#
# [1310 rows x 2 columns]
# 2004
#         make    model
# ...

# %%
#display all the models grouped by year and make

cars_grouped_year_make = df[['model']].groupby([df['year'],df['make']])

# %%
tuple(cars_grouped_year_make)
# Out:
# (((2001, 'ACURA'),
#        model
#   0       CL
#   1       EL
#   2  INTEGRA
#   3      MDX
#   4      NSX
#   5       RL
#   6       TL),
#  ((2001, 'AM GENERAL'),
#       model
#   7  HUMMER),
#  ((2001, 'AMERICAN IRONHORSE'),
#         model
#   8   CLASSIC
#   9    LEGEND
#   10   OUTLAW
#   11   RANGER
#   12  SLAMMER
#   13    TEJAS
#   14  THUNDER),
#  ((2001, 'APRILIA'),
#                       model
#   15           ATLANTIC 500
#   16      ETV 1000 CAPONORD
#   17       MOJITO CUSTOM 50
#   18        MOJITO RETRO 50
#   19             PEGASO 650
#   20  RALLY 50 (AIR COOLED)
#   21                 RS 125
#   22                 RS 250
#   23         RST1000 FUTURA
#   24              RSV MILLE
#   25            RSV MILLE R
#   26           SCARABEO 125
#   27           SCARABEO 150
#   28         SCARABEO 50 2T
#   29     SCARABEO 50 DITECH
#   30           SL1000 FALCO),
#  ((2001, 'ARCTIC CAT'),
#                         model
#   31                  250 2X4
# ...

# %%
for year_make, group in cars_grouped_year_make: #is close to a list of dataframes
    print(year_make) 
    print (f'Sub-total - {group.model.count()}')
# Out:
# (2001, 'ACURA')
# Sub-total - 7
# (2001, 'AM GENERAL')
# Sub-total - 1
# (2001, 'AMERICAN IRONHORSE')
# Sub-total - 7
# (2001, 'APRILIA')
# Sub-total - 16
# (2001, 'ARCTIC CAT')
# Sub-total - 51
# (2001, 'ASTON MARTIN')
# Sub-total - 2
# (2001, 'ATK')
# Sub-total - 7
# (2001, 'AUDI')
# Sub-total - 13
# (2001, 'AVANTI')
# Sub-total - 1
# (2001, 'BENTLEY')
# Sub-total - 3
# (2001, 'BIG DOG')
# Sub-total - 8
# (2001, 'BIMOTA')
# Sub-total - 1
# (2001, 'BLUE BIRD')
# Sub-total - 4
# (2001, 'BMW')
# Sub-total - 46
# (2001, 'BOMBARDIER')
# Sub-total - 6
# (2001, 'BUELL')
# Sub-total - 5
# (2001, 'BUICK')
# Sub-total - 4
# (2001, 'CADILLAC')
# Sub-total - 4
# (2001, 'CANNONDALE')
# Sub-total - 2
# (2001, 'CHANCE COACH TRANSIT BUS')
# Sub-total - 1
# (2001, 'CHEVROLET')
# Sub-total - 42
# (2001, 'CHRYSLER')
# Sub-total - 12
# (2001, 'COBRA')
# Sub-total - 2
# (2001, 'DAEWOO')
# Sub-total - 3
# (2001, 'DODGE')
# Sub-total - 22
# (2001, 'DUCATI')
# Sub-total - 27
# (2001, 'E-TON')
# ...

# %%
df_count_models = df[['model']].groupby([df['year'],df['make']])
df_count_models

# %%
df = pd.read_csv('data.csv')
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
cars_grouped_make = df.groupby(df['Make'])

for make,group in cars_grouped_make:
    print(make)
    print(group[['Make','Model','MSRP']])
# Out:
# Acura
#         Make Model   MSRP
# 2696   Acura    CL  29980
# 2697   Acura    CL  27980
# 2698   Acura    CL  28030
# 2699   Acura    CL  30030
# 2700   Acura    CL  32700
# ...      ...   ...    ...
# 11908  Acura   ZDX  50520
# 11909  Acura   ZDX  46120
# 11910  Acura   ZDX  56670
# 11911  Acura   ZDX  50620
# 11912  Acura   ZDX  50920
#
# [252 rows x 3 columns]
# Alfa Romeo
#            Make Model   MSRP
# 474  Alfa Romeo    4C  63900
# 475  Alfa Romeo    4C  68400
# 476  Alfa Romeo    4C  53900
# 477  Alfa Romeo    4C  55900
# 478  Alfa Romeo    4C  65900
# Aston Martin
#                Make     Model    MSRP
# 3520   Aston Martin       DB7  156300
# 3521   Aston Martin       DB7  151800
# 3522   Aston Martin       DB7  156300
# 3523   Aston Martin       DB7  141800
# 3524   Aston Martin    DB9 GT  235307
# ...             ...       ...     ...
# 11211  Aston Martin  Vanquish  305650
# 11212  Aston Martin  Vanquish  302695
# 11213  Aston Martin  Vanquish  320695
# ...

# %%
cars_grouped_mmake = df[['Vehicle Style','Market Category','MSRP']].groupby(
                    [df['Make'],df['Model'],df['Year']])
list(cars_grouped_mmake)

for make,group in cars_grouped_mmake:
    print (make)
    print (f' Most Expensive: ${group["MSRP"].max()}')
    print (f' Cheapest: ${group["MSRP"].min()}')
    print (f' Mean ${group["MSRP"].mean()}')
# Out:
# ('Acura', 'CL', 2001)
#  Most Expensive: $29980
#  Cheapest: $27980
#  Mean $28980.0
# ('Acura', 'CL', 2002)
#  Most Expensive: $30030
#  Cheapest: $28030
#  Mean $29030.0
# ('Acura', 'CL', 2003)
#  Most Expensive: $32700
#  Cheapest: $28200
#  Mean $30470.0
# ('Acura', 'ILX', 2015)
#  Most Expensive: $31750
#  Cheapest: $27050
#  Mean $29375.0
# ('Acura', 'ILX', 2016)
#  Most Expensive: $34890
#  Cheapest: $27900
#  Mean $31113.333333333332
# ('Acura', 'ILX', 2017)
#  Most Expensive: $34980
#  Cheapest: $27990
#  Mean $31203.333333333332
# ('Acura', 'ILX Hybrid', 2014)
#  Most Expensive: $34600
#  Cheapest: $28900
#  Mean $31750.0
# ('Acura', 'Integra', 1999)
#  Most Expensive: $3381
#  Cheapest: $2799
#  Mean $3045.6666666666665
# ('Acura', 'Integra', 2000)
#  Most Expensive: $7398
#  Cheapest: $3012
#  Mean $3874.5714285714284
# ('Acura', 'Integra', 2001)
#  Most Expensive: $24450
#  Cheapest: $19400
#  Mean $21550.0
# ('Acura', 'Legend', 1993)
#  Most Expensive: $2060
# ...

# %%
df.sort_values(by = 'MSRP', ascending = False).loc[11362]
# Out:
# Make                                     Bugatti
# Model                                Veyron 16.4
# Year                                        2008
# Engine Fuel Type     premium unleaded (required)
# Engine HP                                   1001
# Engine Cylinders                              16
# Transmission Type               AUTOMATED_MANUAL
# Driven_Wheels                    all wheel drive
# Number of Doors                                2
# Market Category          Exotic,High-Performance
# Vehicle Size                             Compact
# Vehicle Style                              Coupe
# highway MPG                                   14
# city mpg                                       8
# Popularity                                   820
# MSRP                                     2065902
# Name: 11362, dtype: object

# %%
df['MSRP'].idxmax() #returns the index of the maximum value of a given series
# Out:
# 11362

# %%
df.loc[df['MSRP'].idxmax()]
# Out:
# Make                                     Bugatti
# Model                                Veyron 16.4
# Year                                        2008
# Engine Fuel Type     premium unleaded (required)
# Engine HP                                   1001
# Engine Cylinders                              16
# Transmission Type               AUTOMATED_MANUAL
# Driven_Wheels                    all wheel drive
# Number of Doors                                2
# Market Category          Exotic,High-Performance
# Vehicle Size                             Compact
# Vehicle Style                              Coupe
# highway MPG                                   14
# city mpg                                       8
# Popularity                                   820
# MSRP                                     2065902
# Name: 11362, dtype: object

# %%
df.shape
# Out:
# (11914, 16)

# %%
df.loc[df['MSRP'].idxmin()] # more computationally efficient to get index first then do an .loc, sorting large DataFrame takes time
# Out:
# Make                              Audi
# Model                              100
# Year                              1992
# Engine Fuel Type      regular unleaded
# Engine HP                          172
# Engine Cylinders                     6
# Transmission Type               MANUAL
# Driven_Wheels        front wheel drive
# Number of Doors                      4
# Market Category                 Luxury
# Vehicle Size                   Midsize
# Vehicle Style                    Sedan
# highway MPG                         24
# city mpg                            17
# Popularity                        3105
# MSRP                              2000
# Name: 17, dtype: object

# %%
cars_grouped_male = df.groupby('Make')
for make,goup in cars_grouped_make:
    print(make)
    print('='  * len(make))
    most_exp_each_make = group['MSRP'].idxmax()
  
    print(df.iloc[most_exp_each_make])
    print("")
# Out:
# Acura
# =====
# Make                                          Volvo
# Model                                          XC90
# Year                                           2016
# Engine Fuel Type     premium unleaded (recommended)
# Engine HP                                       316
# Engine Cylinders                                  4
# Transmission Type                         AUTOMATIC
# Driven_Wheels                       all wheel drive
# Number of Doors                                   4
# Market Category                    Crossover,Luxury
# Vehicle Size                                  Large
# Vehicle Style                               4dr SUV
# highway MPG                                      25
# city mpg                                         20
# Popularity                                      870
# MSRP                                          65700
# Name: 11631, dtype: object
#
# Alfa Romeo
# ...
# Make                                          Volvo
# ...

# %%
df_result = df[['MSRP']].groupby (
    [df['Make'],df['Model'],df['Vehicle Style']]).max()

              
df_result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-732475ebd0a7> in <module>
# ----> 1 df_result = df[['MSRP']].groupby (
#       2     [df['Make'],df['Model'],df['Vehicle Style']]).max()
#       3
#       4
#       5 df_result
#
# NameError: name 'df' is not defined

# %%
most_exp_each_make.dtype
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6c9305b228d0> in <module>
# ----> 1 most_exp_each_make.dtype
#
# NameError: name 'most_exp_each_make' is not defined

# %%
rows = df[['MSRP']].groupby (
    [df['Make'],df['Model']]).idxmax()

              
df.iloc[rows['MSRP'].values][['Make','Model','MSRP']]
# Out:
#         Make       Model   MSRP
# 2700   Acura          CL  32700
# 5811   Acura         ILX  34980
# 5797   Acura  ILX Hybrid  34600
# 5939   Acura     Integra  24450
# 6425   Acura      Legend   2506
# ...      ...         ...    ...
# 11181  Volvo         V90   2200
# 11640  Volvo          XC  36500
# 11597  Volvo        XC60  51300
# 11615  Volvo        XC70  48175
# 11631  Volvo        XC90  65700
#
# [928 rows x 3 columns]
